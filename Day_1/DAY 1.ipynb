# %%
# 1. Checking the python version I'm using
# I went to command prompt in my window search and write python and the python version I'm using is 3.13.2

# %%
# Addition of numbers 
num1 = 3 # first number
num2 = 4 # second number
sum = num1 + num2 # it add the two numbers
print(f"the Total sum of {num1} and {num2} is {sum}") # it print the total sum of the two numbers
# Out:
# the Total sum of 3 and 4 is 7

# %%
#  Subtraction of numbers
num1 = 3 # first number
num2 = 4 # second number
sub = num1 - num2 # it subtract the two numbers
print(sub) # it print the result of the subtraction
# Out:
# -1

# %%
# multiplication of two numbers
num1 = 3 # first number
num2 = 4 # second number
mul = num1 * num2 # it multiply the two numbers
print(f"the product of {num1} and {num2} is {mul}") # it print the product of the two numbers
# Out:
# the product of 3 and 4 is 12

# %%
# modulus of two numbers
num1 = 3 # first number
num2 = 4 # second number
mod = num1 % num2 # it gives the remainder of the two numbers
print(mod) # it print the remainder of the two numbers
# Out:
# 3

# %%
# modulus of two numbers
num1 = 4 # first number
num2 = 3 # second number
mod = num1 % num2 # it gives the remainder of the two numbers
print(mod) # it print the remainder of the two numbers
# Out:
# 1

# %%
# division of two numbers
num1 = 3 # first number
num2 = 4 # second number
div = num1 / num2 # it divide the two numbers
print(div) # it print the result of the division
# Out:
# 0.75

# %%
# exponential of two numnbers
num1 = 3 # first number
num2 = 4 # second number
exp = num1 ** num2 # it gives the exponential of the two numbers
print(exp) # it print the exponential of the two numbers
# Out:
# 81

# %%
# floor division of two numbers
num1 = 3 # first number
num2 = 4 # second number
floor_div = num1 // num2 # it gives the floor division of the two numbers
print(floor_div) # it print the floor division of the two numbers
# Out:
# 0

# %%
# floor division of two numbers
num1 = 4 # first number
num2 = 3 # second number
floor_div = num1 // num2 # it gives the floor division of the two numbers
print(floor_div) # it print the floor division of the two numbers
# Out:
# 1

# %%
# writing strings
my_name = input("enter my name") # it takes my name as input
family_name = input("enter my family name") # it takes my family name as input
my_country_name = input("enter my country name") # it takes my country name as input
print(f"My name is {my_name} {family_name}. I hailed from {my_country_name}. I am enjoying 30 days of python") # it print the output of the input
# Out:
# My name is Maker Panom. I hailed from South Sudan. I am enjoying 30 days of python

# %%
 # check the data type of the variable
num = 10 # it is an integer
num1 = 9.8  # it is a float
num2 = 3.14 # it a float
num3 = 4 - 4j # it is a complex number
my_list = ["Asabeneh","Python","Finland"] # it is a list
print(type(num)) # it print the data type of the variable
print(type(num1)) # it print the data type of the variable
print(type(num2)) # it print the data type of the variable
print(type(num3)) # it print the data type of the variable
print(type(my_list)) # it print the data type of the variable
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'complex'>
# <class 'list'>

# %%
num = 10  # it is an integer
num1 = 9.8  # it is a float
num2 = 3.14  # it is a float
num3 = 4 - 4j  # it is a complex number
my_list = ["Asabeneh", "Python", "Finland"]  # it is a list

print(f"The type of num ({num}) is {type(num)}")
print(f"The type of num1 ({num1}) is {type(num1)}")
print(f"The type of num2 ({num2}) is {type(num2)}")
print(f"The type of num3 ({num3}) is {type(num3)}")
print(f"The type of my_list ({my_list}) is {type(my_list)}")
# Out:
# The type of num (10) is <class 'int'>
# The type of num1 (9.8) is <class 'float'>
# The type of num2 (3.14) is <class 'float'>
# The type of num3 ((4-4j)) is <class 'complex'>
# The type of my_list (['Asabeneh', 'Python', 'Finland']) is <class 'list'>

# %%
# data type of the variable
my_name = input("enter my name") # it takes my name as input
family_name = input("enter my family name") # it takes my family name as input
my_country_name = input("enter my country name") # it takes my country name as input
print(f"My name is {my_name} {family_name}. I hailed from {my_country_name}. I am enjoying 30 days of python") # it print the output of the input
print(type(my_name)) # it print the data type of my name
print(type(family_name)) # it print the data type of family name
print(type(my_country_name)) # it print the data type of my country name
# Out:
# My name is Maker Panom. I hailed from South Sudan. I am enjoying 30 days of python
# <class 'str'>
# <class 'str'>
# <class 'str'>
